# %%
import streamlit as st
from PIL import Image
import io

st.set_page_config(page_title="Personal Finance Tracker UI", layout="wide")
st.title(" Personal Finance Tracker — UI Only (Frontend)")

st.write("This is a frontend-only UI. Backend logic (OCR, DB, ML) can be added later.")


st.sidebar.header("Upload Receipt")
uploaded_file = st.sidebar.file_uploader("Upload image or PDF", type=["jpg", "jpeg", "png", "pdf"])
process_btn = st.sidebar.button("Process Receipt")

col1, col2 = st.columns([2, 1])

with col1:
    st.header(" Receipt Preview / Extracted Data")

    if uploaded_file:
        if uploaded_file.type == "application/pdf":
            st.info("PDF uploaded — preview is not shown in this UI version.")
        else:
            image = Image.open(uploaded_file)
            st.image(image, caption="Uploaded Receipt", use_column_width=True)

        st.subheader(" Extracted Text (Placeholder)")
        st.text_area("OCR Output", "Extracted text will appear here...", height=200)

        st.subheader(" Detected Amount (Placeholder)")
        st.write("Amount: **₹0.00**")

        st.subheader(" Detected Date (Placeholder)")
        st.write("Date: **Not detected**")

        st.subheader(" Predicted Category (Placeholder)")
        st.write("Category: **Other**")

    else:
        st.info("Upload a receipt from the sidebar to preview.")


with col2:
    st.header(" Dashboard (UI Preview)")
    st.subheader("Recent Transactions")

    st.table({
        "Date": ["2025-01-01", "2025-01-03"],
        "Amount": ["₹250", "₹1200"],
        "Category": ["Groceries", "Bills"],
        "Source": ["receipt1.jpg", "receipt2.jpg"]
    })

    st.subheader("Spending by Category")
    st.bar_chart({
        "Groceries": [250],
        "Bills": [1200]
    })

st.markdown("---")
st.write(" This UI is ready. Add backend functions (OCR, ML, DB) as needed.")
# Out:
# 2025-11-27 15:39:03.046 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.049 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.331
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\suket\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-27 15:39:03.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:03.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:10.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:10.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:10.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:10.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:10.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:10.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:10.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:10.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:10.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-27 15:39:10.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
