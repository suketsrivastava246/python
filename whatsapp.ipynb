# %%
import pywhatkit

# %%
pywhatkit.sendwhatmsg_instantly("+919905953663","Hello")

# %%
pywhatkit.sendwhatmsg("+916205995989","Dhan nirankar ji",time_hour=16,time_min=8)
# Out:
# In 86330 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
