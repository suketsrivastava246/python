# %%
pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\suket\anaconda3\lib\site-packages (3.14.4)
# Requirement already satisfied: typing-extensions in c:\users\suket\anaconda3\lib\site-packages (from SpeechRecognition) (4.12.2)
# Requirement already satisfied: standard-aifc in c:\users\suket\anaconda3\lib\site-packages (from SpeechRecognition) (3.13.0)
# Requirement already satisfied: audioop-lts in c:\users\suket\anaconda3\lib\site-packages (from SpeechRecognition) (0.2.2)
# Requirement already satisfied: standard-chunk in c:\users\suket\anaconda3\lib\site-packages (from standard-aifc->SpeechRecognition) (3.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyAudio
# Out:
# Collecting PyAudio
#   Downloading PyAudio-0.2.14-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Downloading PyAudio-0.2.14-cp313-cp313-win_amd64.whl (173 kB)
# Installing collected packages: PyAudio
# Successfully installed PyAudio-0.2.14
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr

# %%
mic=sr.Recognizer()

# %%
with sr.Microphone() as source:
    print("Start speaking ...")
    voice= mic.listen(source)
    text =mic.recognize_google(voice)
    print("You said this",text)
# Out:
# Start speaking ...

# %%
import pywhatkit

# %%
with sr.Microphone() as s:
    print("Say Anything ..")
    voice = mic.listen(s)
    text=mic.recognize_google(voice)
    print(text)
